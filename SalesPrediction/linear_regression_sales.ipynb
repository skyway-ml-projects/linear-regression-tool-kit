# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# ### Check Duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Check Null Values

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Outlier Analysis

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['TV'], ax = axs[0])
plt2 = sns.boxplot(df['Newspaper'], ax = axs[1])
plt3 = sns.boxplot(df['Radio'], ax = axs[2])
plt.tight_layout()

# %%
sns.boxplot(df['Sales'])
plt.show()

# %%
# Let's see how Sales are related with other variables using scatter plot.
sns.pairplot(df, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.show()

# %%
# Let's see the correlation between different variables.
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ### Getting the inputs and output

# %%
X = df.iloc[:,[0]].values

# %%
X
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
y = df.iloc[:,-1].values

# %%
y
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 13.2,
#        17.4, 11.9, 17.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 17.9,
#         8.5, 16.1, 10.6, 23.2, 19.8,  9.7, 16.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 20.7, 14. , 16. , 11.3,
#        11. , 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 17.3, 11.3, 13.6, 21.7, 20.2, 12. , 16. ,
#        12.9, 16.7, 14. ,  7.3, 19.4, 22.2, 11.5, 16.9, 16.7, 20.5, 25.4,
#        17.2, 16.7, 23.8, 19.8, 19.7, 20.7, 15. ,  7.2, 12. ,  5.3, 19.8,
#        18.4, 21.8, 17.1, 20.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 16.6, 15.2, 19.7, 10.6,  6.6, 11.9, 24.7,  9.7,  1.6, 17.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
#        10.4, 12.3, 10.3, 18.2, 25.4, 10.9, 10.1, 16.1, 11.6, 16.6, 16. ,
#        20.6,  3.2, 15.3, 10.1,  7.3, 12.9, 16.4, 13.3, 19.9, 18. , 11.9,
#        16.9,  8. , 17.2, 17.1, 20. ,  8.4, 17.5,  7.6, 16.7, 16.5, 27. ,
#        20.2, 16.7, 16.8, 17.6, 15.5, 17.2,  8.7, 26.2, 17.6, 22.6, 10.3,
#        17.3, 20.9,  6.7, 10.8, 11.9,  5.9, 19.6, 17.3,  7.6, 14. , 14.8,
#        25.5, 18.4])

# %% [markdown]
# ### Creating the Training Set and the Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Part 2 - Building and training the model

# %% [markdown]
# ### Building the model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Inference

# %% [markdown]
# Making the predictions of the data points in the test set

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([10.90227673,  9.85532218, 12.05828903, 22.92589531, 16.40969385,
#        10.19340125,  7.60327934, 20.22126274,  8.42666546, 17.90378523,
#        21.37727504, 11.88379661, 15.66810105, 17.36940218, 11.29488468,
#        13.68324973, 21.61174924,  7.16704828, 11.20218558, 18.76534158,
#        22.81138465, 14.77928027, 16.67688538, 14.31033188, 10.04617327,
#        13.84138349, 16.15886099, 18.30729896, 19.34334773,  8.49755301,
#        10.82593629, 17.97467278, 22.43513536, 20.30850895,  7.84865931,
#         8.14856816, 10.37879945, 16.98770001, 10.85865362,  8.49210012,
#         9.14099382,  8.84653786, 14.92105536, 18.55813182, 18.87439934,
#        12.72899429,  7.59782645,  8.05041617, 13.98315858, 12.83259917])

# %% [markdown]
# Making the prediction of a single data point with AT = 15, V = 40, AP = 1000, RH = 75

# %% [markdown]
# ## Part 3: Evaluating the model

# %% [markdown]
# ### intercept (c)

# %%
model.intercept_
# Out:
# np.float64(7.128878060785404)

# %% [markdown]
# ### coef(M)

# %%
model.coef_
# Out:
# array([0.05452888])

# %% [markdown]
# ### R-Score

# %%
model.score(X_train,y_train)
# Out:
# 0.8101117868824258

# %%
model.score(X_test,y_test)
# Out:
# 0.8053611644334993

# %% [markdown]
# ### R-Squared

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.8053611644334993

# %% [markdown]
# ### Adjusted R-Squared

# %%
k = X_test.shape[1]
n = X_test.shape[0]
adj_r2 = 1 - (1-r2)*(n-1)/(n-k-1)

# %%
adj_r2
# Out:
# 0.8013061886925305

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()

# %%
y_train_pred = model.predict(X_train)
res = (y_train - y_train_pred)

# %%
res
# Out:
# array([-0.71614935,  0.05674342, -3.36830843,  3.28873157,  0.53368089,
#        -0.82602744, -1.70038773, -0.13511028, -1.57097676, -2.0269389 ,
#        -3.88993769, -1.20378523, -1.84343888, -0.56098245, -0.46967562,
#         0.40018423, -1.25361548,  1.95564966, -1.90357786,  0.71056821,
#         3.48873157, -0.45210697, -1.25343319,  0.50876118, -0.07455655,
#         3.58385065, -1.25555464,  0.74177703,  0.67873726,  1.50887741,
#        -0.2493475 , -1.42011882,  0.12637999, -1.61188137, -2.54320642,
#         0.52236037,  3.93322516, -0.21811359,  0.97518255, -1.98049025,
#        -0.51090384,  1.86676281,  2.00814824, -3.18491545,  1.73450121,
#        -5.41701983,  4.77207439, -0.95420334,  1.38982533,  0.39039729,
#        -0.46686599,  0.65419131, -1.62374877,  2.42402609, -1.48528004,
#        -1.04149972,  0.86655544,  1.72238545, -1.20545095,  0.31950975,
#         3.34926022, -1.0768603 ,  0.28215985,  2.53614185,  1.2545559 ,
#         1.49799671,  0.92217808, -4.43565716,  1.83737692, -1.03798599,
#         4.61617831, -2.12333403,  0.58234214,  3.67107178, -2.55610152,
#        -1.72842233,  1.10999625, -2.5192985 , -1.61966308,  2.90673088,
#         1.5357112 , -1.17403475,  2.92920554, -1.15402105, -4.15244648,
#         1.40112078,  3.05085988, -1.3884041 , -1.38503168, -1.43622912,
#        -1.58673838, -2.60787092, -5.18042419, -1.35571185,  0.40862905,
#         0.84458667,  0.66619085,  2.49788049, -2.43855795,  0.35158905,
#        -1.88692067,  0.38845813,  1.92669442,  0.62092711,  0.48567358,
#         4.114148  , -5.19730465,  5.55840914, -0.44729211, -1.79566401,
#         3.20696333, -2.12687284, -1.38518889, -0.10494506,  0.39790557,
#        -0.47385246,  0.77091457,  0.94750336, -2.63143934,  5.00969773,
#        -0.47861716,  2.69881703,  0.06509709, -2.45422842,  1.37600287,
#         1.69902441,  3.37570435,  0.20974789,  0.5003916 , -4.46452126,
#        -3.015901  , -2.90490407, -1.82413844, -2.75610152,  1.51723108,
#         1.93853674,  5.17643352, -0.23129803,  0.95622162,  0.31442144,
#         2.83477465,  3.71736321, -2.57403475, -2.42374877,  2.32514493,
#        -1.32475139, -2.16677484, -1.89488468,  2.98964304, -0.59764416])

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)                  # Plot heading 
plt.xlabel('y_train - y_train_pred', fontsize = 15)         # X-label
plt.show()
# Out:
# C:\Users\ganesh10\AppData\Local\Temp\ipykernel_22668\3003513444.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(res, bins = 15)

# %%
plt.scatter(X_train,res)
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, 'r')
plt.show()
