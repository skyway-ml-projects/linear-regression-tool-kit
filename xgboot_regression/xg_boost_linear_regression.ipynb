# %% [markdown]
# # XGBoost Regressor

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Checking missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### Check Duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ### Handling categorical variables

# %% [markdown]
# Sex column

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['sex'] = df['sex'].apply(lambda x : 1 if x== 'male' else 0).astype(int)

# %%
df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %% [markdown]
# smoker

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['smoker'] = df['smoker'].apply(lambda x : 1 if x == 'yes' else  0)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %% [markdown]
# Region column

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(df['region'],drop_first=True).astype(int)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
df = pd.concat([region_dummies,df],axis=1)

# %%
df
# Out:
#       northwest  southeast  southwest  age  sex     bmi  children  smoker  \
# 0             0          0          1   19    0  27.900         0       1
# 1             0          1          0   18    1  33.770         1       0
# 2             0          1          0   28    1  33.000         3       0
# 3             1          0          0   33    1  22.705         0       0
# 4             1          0          0   32    1  28.880         0       0
# ...         ...        ...        ...  ...  ...     ...       ...     ...
# 1333          1          0          0   50    1  30.970         3       0
# 1334          0          0          0   18    0  31.920         0       0
# 1335          0          1          0   18    0  36.850         0       0
# 1336          0          0          1   21    0  25.800         0       0
# 1337          1          0          0   61    0  29.070         0       1
#
#          region      charges
# 0     southwest  16884.92400
# 1     southeast   1725.55230
# 2     southeast   4449.46200
# 3     northwest  21984.47061
# 4     northwest   3866.85520
# ...         ...          ...
# 1333  northwest  10600.54830
# 1334  northeast   2205.98080
# 1335  southeast   1629.83350
# 1336  southwest   2007.94500
# 1337  northwest  29141.36030
#
# [1338 rows x 10 columns]

# %%
df.drop(['region'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    northwest  southeast  southwest  age  sex     bmi  children  smoker  \
# 0          0          0          1   19    0  27.900         0       1
# 1          0          1          0   18    1  33.770         1       0
# 2          0          1          0   28    1  33.000         3       0
# 3          1          0          0   33    1  22.705         0       0
# 4          1          0          0   32    1  28.880         0       0
#
#        charges
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %% [markdown]
# ### Getting the inputs and output

# %%
X = df.iloc[:,:-1].values

# %%
y = df.iloc[:,-1].values

# %%
X
# Out:
# array([[ 0.  ,  0.  ,  1.  , ..., 27.9 ,  0.  ,  1.  ],
#        [ 0.  ,  1.  ,  0.  , ..., 33.77,  1.  ,  0.  ],
#        [ 0.  ,  1.  ,  0.  , ..., 33.  ,  3.  ,  0.  ],
#        ...,
#        [ 0.  ,  1.  ,  0.  , ..., 36.85,  0.  ,  0.  ],
#        [ 0.  ,  0.  ,  1.  , ..., 25.8 ,  0.  ,  0.  ],
#        [ 1.  ,  0.  ,  0.  , ..., 29.07,  0.  ,  1.  ]], shape=(1338, 8))

# %%
y
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603], shape=(1338,))

# %% [markdown]
# ### Creating the Training Set and the Test Set

# %%
from  sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %% [markdown]
# ## Part 2 - Building and training the model

# %% [markdown]
# ### Building the model

# %%
import xgboost

model = xgboost.XGBRegressor(max_depth = 2,learning_rate = 0.15,n_estimators = 100)

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.15, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Inference

# %% [markdown]
# Making the predictions of the data points in the test set

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([11827.391 ,  9767.402 , 46960.78  , 14248.177 , 11200.489 ,
#         4102.413 ,  2818.4287, 13546.435 ,  9248.225 ,  7251.022 ,
#         6622.1587, 12078.967 ,  9164.045 ,  5648.3354, 20058.355 ,
#        11658.084 , 14058.915 ,  5748.732 ,  8089.728 , 35833.758 ,
#        25949.348 , 14364.222 , 12389.957 , 24671.47  ,  3158.3093,
#         7943.4946,  4159.0063,  8172.167 ,  4748.273 , 11338.687 ,
#         8393.65  , 48216.1   , 15141.718 , 11687.725 , 17492.408 ,
#         5222.3843, 13106.277 , 38706.25  , 38665.582 ,  2562.1018,
#         4345.38  ,  4290.494 , 20590.133 , 46755.883 , 37197.793 ,
#         5569.596 , 11658.084 ,  7420.917 ,  4681.164 , 12381.438 ,
#         5287.9126,  4811.111 , 25672.484 , 45879.957 , 11024.6455,
#         6118.865 ,  4529.0728, 10508.492 , 10435.158 , 15734.237 ,
#         2307.6348, 45700.805 , 17292.734 , 11132.223 , 14814.238 ,
#         9784.796 , 35126.074 , 39280.266 ,  3674.0923, 10596.132 ,
#        14746.579 , 12049.567 , 19241.797 , 15135.357 , 14301.882 ,
#        14947.475 ,  8104.869 , 10449.951 , 20863.14  , 47504.8   ,
#        12053.253 , 44363.355 ,  3790.643 ,  9120.891 , 42945.934 ,
#        20966.076 ,  3983.4604,  5065.365 , 16477.115 , 37781.977 ,
#         7914.006 , 11919.812 ,  4583.6704,  9910.836 ,  6759.375 ,
#         6532.279 , 43145.15  , 35863.34  ,  7313.844 , 10759.498 ,
#         4203.9795,  7534.1167,  6545.9233, 37610.543 , 23910.994 ,
#         4674.9106, 11473.758 ,  5858.684 , 12542.628 , 43310.246 ,
#        13295.742 ,  6056.277 , 11138.474 , 35071.945 , 47113.355 ,
#         8202.481 ,  2404.7153, 10447.943 , 15317.169 ,  9994.383 ,
#        42908.855 , 12622.675 , 13242.162 ,  8914.122 , 10289.655 ,
#         6109.9326, 25232.05  , 24908.432 , 47301.133 ,  4855.7505,
#        10916.359 ,  3910.1191,  7597.591 ,  9575.093 , 33572.89  ,
#        36043.457 , 22399.346 , 11801.776 , 26409.766 ,  5890.022 ,
#         3853.4658, 12576.2705, 12861.374 , 12327.134 ,  6073.304 ,
#        14761.139 , 15547.084 ,  5768.0454,  2260.6772, 12044.672 ,
#         7956.824 , 39998.254 , 11607.889 ,  4246.693 ,  4711.702 ,
#         8051.9375,  4725.209 ,  2823.7786, 12427.332 , 11945.146 ,
#         7015.695 , 13320.073 , 14301.882 ,  9785.424 ,  3644.9045,
#         8671.5625, 16176.296 ,  7672.7446,  6193.1675,  2255.692 ,
#         7180.2925,  7100.088 , 11381.841 ,  4679.026 ,  6021.875 ,
#         7652.5425,  5219.7627,  6464.2544, 29417.703 ,  2755.606 ,
#        14263.074 ,  8826.5   , 12491.732 ,  4704.0215,  6119.825 ,
#        27226.727 ,  3790.643 ,  3576.9148, 14799.485 , 12447.151 ,
#        42187.16  ,  6225.223 ,  6212.003 , 24677.46  ,  5613.982 ,
#         3947.814 ,  9185.401 ,  9070.305 ,  6829.725 ,  5895.94  ,
#        12967.542 , 44360.805 , 14263.074 , 20734.611 ,  7251.022 ,
#        43896.832 ,  5376.3535, 11899.287 ,  7985.394 ,  2256.3203,
#        11501.614 , 14698.338 ,  6391.9624,  3844.504 ,  6855.017 ,
#         3872.5261,  8000.1504,  5581.2266, 15939.3545,  6876.8647,
#         8099.9863,  7628.6665,  9999.622 ,  4026.0903, 11635.621 ,
#        15812.424 , 15054.4375, 12275.793 ,  6188.2383,  3926.8535,
#         3401.3872, 10030.562 , 13537.985 ,  7134.169 ,  5233.385 ,
#         7382.273 , 11724.314 , 36589.32  ,  7471.4194, 13331.905 ,
#         7273.0396, 39401.47  ,  7826.6787,  8827.317 , 11319.018 ,
#        12904.719 ,  4025.591 , 10622.376 ,  2643.5251,  6738.555 ,
#        19925.219 , 45140.855 ,  5199.2754,  4553.3584,  3003.5361,
#         2383.11  ,  8926.588 ,  3659.5925,  6941.5586,  5217.4536,
#         8652.336 , 26797.12  , 43665.938 , 17898.654 ,  7712.519 ,
#        11833.56  , 41506.76  ,  9994.383 , 39225.098 ,  2975.5537,
#        40780.594 ,  6200.484 , 12967.542 ,  6459.1016, 39478.992 ,
#         7533.4883, 11734.688 , 10575.299 ,  4725.209 , 16214.927 ,
#        12639.094 ,  7234.769 , 15487.261 ,  4426.449 ,  8708.549 ,
#         5185.2593,  9188.247 , 23651.334 ,  4553.987 ,  2381.2737,
#         3937.7483, 48286.758 , 10516.212 ,  6532.279 , 14364.222 ,
#        12967.542 , 35117.37  ,  8206.8   ,  6292.191 , 10110.102 ,
#         4291.8154,  4709.8423, 18391.969 , 19501.06  , 14797.704 ,
#         4232.743 ,  4942.4863, 11089.776 , 12491.732 , 15976.195 ,
#        22799.027 ,  6690.519 , 17019.646 ,  4354.6377,  5846.3555,
#         5839.411 ,  9768.849 ,  3003.675 ,  8584.351 , 46048.63  ,
#         5950.5986,  6296.9517,  2503.6443, 10218.934 ,  5249.169 ,
#        12146.215 , 45607.105 , 19976.3   , 11501.614 , 44321.117 ,
#        14364.222 ,  7251.022 , 11197.542 ,  5630.2935, 27495.303 ],
#       dtype=float32)

# %%
y_test
# Out:
# array([ 9724.53    ,  8547.6913  , 45702.02235 , 12950.0712  ,
#         9644.2525  ,  4500.33925 ,  2198.18985 , 11436.73815 ,
#         7537.1639  ,  5425.02335 ,  6753.038   , 10493.9458  ,
#         7337.748   ,  4185.0979  , 18310.742   , 10702.6424  ,
#        12523.6048  ,  3490.5491  ,  6457.8434  , 33475.81715 ,
#        23967.38305 , 12643.3778  , 23045.56616 , 23065.4207  ,
#         1674.6323  ,  4667.60765 ,  3732.6251  ,  7682.67    ,
#         3756.6216  ,  8413.46305 ,  8059.6791  , 48970.2476  ,
#        12979.358   , 20630.28351 , 14571.8908  ,  4137.5227  ,
#         8347.1643  , 51194.55914 , 40003.33225 ,  1880.487   ,
#         5458.04645 ,  2867.1196  , 20149.3229  , 47496.49445 ,
#        36149.4835  , 26018.95052 , 19749.38338 ,  6940.90985 ,
#         4718.20355 , 22192.43711 ,  2899.48935 , 18838.70366 ,
#        23568.272   , 46255.1125  , 24227.33724 ,  3268.84665 ,
#         2322.6218  ,  8827.2099  , 14478.33015 , 13112.6048  ,
#         1253.936   , 46718.16325 , 13919.8229  ,  9630.397   ,
#        10736.87075 ,  9880.068   , 32548.3405  , 38746.3551  ,
#         3180.5101  ,  8162.71625 , 13041.921   , 11554.2236  ,
#        16232.847   , 13887.9685  , 13012.20865 , 13217.0945  ,
#         7147.105   ,  7731.4271  , 20296.86345 , 47403.88    ,
#        11658.37915 , 45863.205   ,  2055.3249  ,  7441.053   ,
#        41034.2214  , 18972.495   ,  3410.324   ,  2699.56835 ,
#        12333.828   , 36837.467   ,  6334.34355 , 10214.636   ,
#        17878.90068 ,  8515.7587  ,  4518.82625 ,  5148.5526  ,
#        42303.69215 , 38998.546   ,  5327.40025 , 10602.385   ,
#         1824.2854  ,  5377.4578  ,  4349.462   , 37742.5757  ,
#        32787.45859 ,  3353.4703  , 10577.087   ,  3556.9223  ,
#        11944.59435 , 52590.82939 , 12475.3513  ,  4266.1658  ,
#         9249.4952  , 33732.6867  , 48675.5177  ,  7729.64575 ,
#         1964.78    ,  8444.474   , 12347.172   ,  9301.89355 ,
#        42124.5153  ,  9991.03765 , 14319.031   ,  5428.7277  ,
#         7626.993   ,  4906.40965 , 23401.30575 , 21098.55405 ,
#        48173.361   ,  1917.3184  ,  8219.2039  ,  1725.5523  ,
#         5976.8311  ,  9361.3268  , 22144.032   , 35491.64    ,
#        19515.5416  , 10107.2206  , 23244.7902  ,  2789.0574  ,
#         2261.5688  , 10594.50155 ,  9304.7019  , 10435.06525 ,
#         4894.7533  , 14313.8463  , 28287.89766 , 14426.07385 ,
#         1627.28245 , 25517.11363 ,  6555.07035 , 39611.7577  ,
#         9964.06    ,  1720.3537  ,  2730.10785 ,  6500.2359  ,
#         2643.2685  ,  1719.4363  , 11085.5868  , 10115.00885 ,
#         4846.92015 , 12982.8747  , 28923.13692 ,  9391.346   ,
#         4544.2348  , 17128.42608 , 13844.506   ,  6113.23105 ,
#         4441.21315 ,  1633.9618  ,  4058.71245 ,  4435.0942  ,
#         8310.83915 ,  1986.9334  ,  4260.744   ,  4504.6624  ,
#         4428.88785 ,  6117.4945  , 30184.9367  ,  1708.92575 ,
#        11187.6567  ,  6796.86325 , 11356.6609  ,  2498.4144  ,
#        27375.90478 , 28101.33305 ,  2254.7967  ,  2597.779   ,
#        14692.66935 , 10370.91255 , 41097.16175 ,  3981.9768  ,
#         5472.449   , 21223.6758  ,  2534.39375 ,  1972.95    ,
#         6406.4107  ,  6551.7501  ,  4058.1161  ,  4243.59005 ,
#        11512.405   , 46889.2612  , 12268.63225 , 19199.944   ,
#         4433.3877  , 42969.8527  , 23241.47453 ,  9140.951   ,
#         5836.5204  ,  1149.3959  ,  8765.249   , 14043.4767  ,
#         5312.16985 , 10795.93733 ,  6282.235   ,  1969.614   ,
#         6746.7425  ,  5354.07465 , 14001.2867  ,  6877.9801  ,
#         6196.448   ,  7986.47525 ,  8277.523   ,  3206.49135 ,
#        11848.141   , 14210.53595 , 12265.5069  , 11837.16    ,
#         6652.5288  ,  2137.6536  ,  1131.5066  ,  8342.90875 ,
#        12244.531   ,  4561.1885  , 17626.23951 ,  6875.961   ,
#         9447.3824  , 34254.05335 ,  6067.12675 , 11729.6795  ,
#         5383.536   , 37465.34375 ,  7371.772   ,  7325.0482  ,
#         8410.04685 , 10461.9794  ,  3279.86855 ,  7727.2532  ,
#         2731.9122  ,  6858.4796  , 19521.9682  , 47305.305   ,
#         3987.926   ,  3238.4357  ,  7323.734819,  1704.5681  ,
#         7445.918   ,  1629.8335  ,  4877.98105 ,  3561.8889  ,
#         8605.3615  , 24520.264   , 45710.20785 , 15019.76005 ,
#         6664.68595 , 20709.02034 , 40932.4295  ,  9500.57305 ,
#        40182.246   ,  1137.4697  , 38511.6283  ,  4670.64    ,
#        13019.16105 ,  4189.1131  , 38709.176   ,  5594.8455  ,
#        27346.04207 ,  9788.8659  ,  2362.22905 , 13224.693   ,
#        12222.8983  ,  4320.41085 , 12730.9996  ,  2203.47185 ,
#         6079.6715  ,  3591.48    ,  8596.8278  , 21771.3423  ,
#         2927.0647  ,  1708.0014  ,  2803.69785 , 48517.56315 ,
#         9282.4806  ,  4738.2682  , 12269.68865 , 11879.10405 ,
#        34166.273   ,  6496.886   ,  4751.07    ,  8457.818   ,
#         1639.5631  ,  2566.4707  , 14455.64405 , 16577.7795  ,
#        13457.9608  ,  2721.3208  , 18218.16139 ,  8615.3     ,
#         9722.7695  , 14283.4594  , 21472.4788  ,  5972.378   ,
#        14711.7438  ,  2128.43105 ,  5438.7491  ,  3935.1799  ,
#         8534.6718  , 11884.04858 ,  6837.3687  , 42983.4585  ,
#         3925.7582  , 18903.49141 ,  2117.33885 ,  8283.6807  ,
#         3366.6697  , 11833.7823  , 47928.03    , 17361.7661  ,
#         9290.1395  , 42560.4304  , 13224.05705 ,  4433.9159  ,
#         9377.9047  ,  3597.596   , 29141.3603  ])

# %% [markdown]
# ## Part 3: Evaluating the model

# %% [markdown]
# ### R-Squared

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.8996195660637195

# %% [markdown]
# ### Adjusted R-Squared

# %%
k = X_test.shape[1]
n = X_test.shape[0]
r2_adj = 1 - (1-r2) * (n-1)/(n-k-1)

# %%
r2_adj
# Out:
# 0.8971562425315408

# %% [markdown]
# ### k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
r2s = cross_val_score(estimator=model,X=X,y=y,scoring='r2',cv=10)
print("Average R-Squared:{:.3f}".format(r2s.mean()))
print("Standard Deviation :{:.3f}".format(r2s.std()))
# Out:
# Average R-Squared:0.860
# Standard Deviation :0.044

# %% [markdown]
# ## Train two models

# %%
from sklearn.linear_model import LinearRegression

models =  {
    "Linear Regression": LinearRegression(),
    "XGBoost Regressor": xgboost.XGBRegressor(max_depth = 2,learning_rate = 0.15,n_estimators = 100)
}
fitted = {name:mdl.fit(X_train,y_train)  for  name,mdl in models.items()}

# %% [markdown]
# ### Evaluate

# %%
def evalute(clf,Xtr,ytr,Xte,yte):
    yhat_tr = clf.predict(Xtr)
    yhat_te = clf.predict(Xte)
    matrics = {
        "R2_Train":r2_score(ytr,yhat_tr),
        "R2_Test":r2_score(yte,yhat_te),
        "R2_ADJ_Train" : 1 - (1-(r2_score(ytr,yhat_tr))) * ((Xtr.shape[0])-1)/((Xtr.shape[0]) - (Xtr.shape[1]) -1),
        "R2_ADJ_Test" : 1 - (1-(r2_score(yte,yhat_te))) * ((Xte.shape[0])-1)/((Xte.shape[0]) - (Xte.shape[1]) -1)
    }
    return matrics

results = {}
for name,clf in fitted.items():
    m = evalute(clf,X_train,y_train,X_test,y_test)
    results[name] = m

# %%
pd.DataFrame(results).T.sort_values('R2_Test', ascending=False)
# Out:
#                    R2_Train   R2_Test  R2_ADJ_Train  R2_ADJ_Test
# XGBoost Regressor  0.872269  0.899620      0.871241     0.897156
# Linear Regression  0.734059  0.795879      0.731919     0.790870

# %% [markdown]
# com123
